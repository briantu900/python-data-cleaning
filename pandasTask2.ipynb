# %%
import pandas as pd

# %%
#data exploration
df = pd.read_csv('Data_Analyst_Sample.csv')
df.info()
df.isnull().sum()
#52481 rows and 10 columns
#Campaign Name has 36 missing values, Date has 33 missing values, Impressions has 30 missing values and finally Cost has 23 missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49218 entries, 0 to 49217
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Campaign Name             49182 non-null  object
#  1   Campaign ID               49217 non-null  float64
#  2   Placement                 49217 non-null  object
#  3   Date                      49190 non-null  object
#  4   Impressions               49187 non-null  float64
#  5   Clicks                    49217 non-null  float64
#  6   Cost                      49194 non-null  float64
#  7   Video Completions         49217 non-null  float64
#  8   Find A Dealer Conversion  49217 non-null  float64
#  9   Online Brochure Download  49217 non-null  float64
# dtypes: float64(7), object(3)
# memory usage: 3.8+ MB
# Campaign Name               36
# Campaign ID                  1
# Placement                    1
# Date                        28
# ...

# %%
df.sample(15)
# Out:
#                                            Campaign Name  Campaign ID  \
# 33339  CY21_Q1_LOC_DE_Mercedes_C-Class_ProgrammaticDi...     25336411
# 32566  CY21_Q1_LOC_DE_Mercedes_C-Class_ProgrammaticVi...     25337479
# 40418  CY21_Q1_LOC_IT_Smart_Fortwo_ProgrammaticDispla...     25348019
# 5980   CY21_Q1_LOC_BE_MercedesS-Class_ProgrammaticDis...     25413759
# 24426  CY21_Q1_LOC_FR_Mercedes_C-Class_ProgrammaticDi...     25350364
# 25149  CY21_Q1_LOC_FR_Smart_Fortwo_ProgrammaticVideo_...     25445106
# 16054  CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticDispla...     25414407
# 2041   CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticVi...     25337587
# 33613  CY21_Q1_LOC_DE_Mercedes_C-Class_ProgrammaticDi...     25336411
# 3280   CY21_Q1_LOC_BE_MercedesS-Class_ProgrammaticDis...     25413759
# 51364  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
# 2353   CY21_Q1_LOC_BE_MercedesS-Class_ProgrammaticDis...     25413759
# ...

# %%
df.describe()
# Out:
#         Campaign ID   Impressions        Clicks          Cost  \
# count  5.248100e+04  5.245100e+04  52481.000000  52458.000000
# mean   2.537639e+07  4.841354e+03     29.774356     28.538750
# std    4.054270e+04  2.562214e+04    176.324974    167.347141
# min    2.492233e+07  0.000000e+00      0.000000      0.000000
# 25%    2.533641e+07  6.100000e+01      0.000000      0.270000
# 50%    2.536894e+07  4.120000e+02      1.000000      1.970000
# 75%    2.541376e+07  2.258000e+03      4.000000     11.530000
# max    2.553608e+07  2.537059e+06   7662.000000  11826.480000
#
#        Video Completions  Find A Dealer Conversion  Online Brochure Download
# count       52481.000000              52481.000000              52481.000000
# mean          995.629104                  3.051790                  1.231589
# std          5552.026890                 21.285292                  8.802559
# min             0.000000                  0.000000                  0.000000
# ...

# %%
col_list = []
for column in df.columns:
  if df[column].dtype == object:
    col_list.append(column)
#df_clean = df.dropna(subset = [col for col in df.columns if df[col].dtype == 'object'])

df = df.fillna(0)
df.isnull().sum()
# Out:
# Campaign Name               0
# Campaign ID                 0
# Placement                   0
# Date                        0
# Impressions                 0
# Clicks                      0
# Cost                        0
# Video Completions           0
# Find A Dealer Conversion    0
# Online Brochure Download    0
# dtype: int64

# %%
error_nums = []
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp(?!ecting)',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Prospecting',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_FR_Merc_C-Class_ProgrammaticVideo_Prospecting',na=False)].shape[0])
print(error_nums)
print(sum(error_nums),'errors')
# Out:
# [0, 14, 0, 0]
# 14 errors

# %%
error_nums.clear()
df["Campaign Name"] = df["Campaign Name"].replace(["CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting", "CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp", "CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Prospecting", "CY21_Q1_LOC_FR_Merc_C-Class_ProgrammaticVideo_Prospecting"],["CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDisplay_Prospecting","CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prospecting","CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay_Prospecting","CY21_Q1_LOC_FR_Mercedes_C-Class_ProgrammaticVideo_Prospecting"])

error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp(?!ecting)',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Prospecting',na=False)].shape[0])
error_nums.append(df[df['Campaign Name'].str.contains('CY21_Q1_LOC_FR_Merc_C-Class_ProgrammaticVideo_Prospecting',na=False)].shape[0])
print(error_nums)
print(sum(error_nums),'errors')
# Out:
# [0, 0, 0, 0]
# 0 errors
